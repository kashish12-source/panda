# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# matrix plot means does not contain the x and y axis it contain divisions

# %% [markdown]
# **types**

# %% [raw]
# heat map
# clusture map
# pivot table heat map
# in this we use the concept of pivot table
# for using the pivot table we use the two dataset so we load the

# %%
flights=sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
tip=sns.load_dataset('tips')
tip
# Out:
# -----------------------------------
# NameErrorTraceback (most recent call last)
# Cell In[4], line 1
# ----> 1 tip=sns.load_dataset('tips')
#       2 tip
#
# NameError: name 'sns' is not defined

# %% [raw]
# corelation means that out of three columns if we want to predict the one of them so we need the relation between any two of the columns
# and then we decide if these two are able to predict the other one or not

# %% [raw]
# corealtion will be lie btween -1  to 1
# as let us assume that their is a table with colums A B C
# A is increasing and C is also increasing then the corelation is 1
# B is decreasing C is increasing the relation is -1
#      and to show this corelations we use heat maps

# %%
# here we calculate the corelations :
# for corelations the values must be numeric it can be qualitative or quantitative

# %%
tipscorr=tip[['total_bill','tip','size']]
tipscorr
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
# since we have selected the columns with the numeric value now we calculate the corelations
tipscorr.corr()
# this will show the corelations in the form of self_matrix
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# now we create the heatmap 
sns.heatmap(tipscorr.corr())
# Out:
# <Axes: >

# %%
# this will show the corelation in the form of the color diffrence
# the darkest one will have lowest corelation 
# and the brightest one will have the highest corelation
# another thing that we can use is annot that will show the data on the boxes 
sns.heatmap(tipscorr.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# **cluster map**

# %%
import scipy

# %%
sns.clustermap(tipscorr.corr())
# thsi will require the installation of the scipy

# %% [markdown]
# **pivot table heatmap**

# %%
pivflights=flights.pivot_table(index="month",columns="year",values="passengers")
pivflights
# Out:
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# ...

# %%
pivflights.corr()
# Out:
# month       Jan       Feb       Mar       Apr       May       Jun       Jul  \
# month
# Jan    1.000000  0.998247  0.993215  0.995918  0.996823  0.998700  0.997717
# Feb    0.998247  1.000000  0.991813  0.994752  0.995039  0.997296  0.994991
# Mar    0.993215  0.991813  1.000000  0.991589  0.994742  0.994923  0.991882
# Apr    0.995918  0.994752  0.991589  1.000000  0.998290  0.994910  0.994981
# May    0.996823  0.995039  0.994742  0.998290  1.000000  0.995804  0.996357
# Jun    0.998700  0.997296  0.994923  0.994910  0.995804  1.000000  0.998211
# Jul    0.997717  0.994991  0.991882  0.994981  0.996357  0.998211  1.000000
# Aug    0.997479  0.995954  0.994852  0.992308  0.995219  0.997674  0.997756
# Sep    0.996372  0.995011  0.994969  0.995188  0.996724  0.998527  0.998808
# Oct    0.997920  0.996401  0.992312  0.996277  0.997837  0.997856  0.998987
# Nov    0.995648  0.994475  0.994334  0.992867  0.996645  0.997113  0.997343
# ...

# %%
sns.heatmap(pivflights)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
import cufflinks as cf
import seaborn as sns

# %%
import plotly.offline

# %%
tips=sns.load_dataset('tips')

# %%
tips['tip'].iplot()
# Out:
# -----------------------------------
# ValueErrorTraceback (most recent call last)
# Cell In[8], line 1
# ----> 1 tips['tip'].iplot()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\cufflinks\plotlytools.py:839, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     837 	if not isinstance(text,list):
#     838 		text=self[text].values
# ...
